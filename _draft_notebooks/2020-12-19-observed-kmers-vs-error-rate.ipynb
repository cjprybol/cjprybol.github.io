# %% [markdown]
# ---
# layout: post
# ---

# %% [markdown]
# Objective: Evaluate how the number of unique kmers observed increases relative to depth of coverage and error rate
#
# I know that when resequencing a genome with a non-zero error rate and high redundancy (depth of coverage), eventually the number or erroneous kmers will dominate the number of true kmers that actually exist in the sample.
# In order to avoid using an unnecessarily large amount of memory storing information for kmers that don't exist, error correction should happen at a k-size where some, but not all, kmers are erroneous.
# Said another way, the idea is to do an iterative search (at a larger k) and bound (by correcting the erroneous ones)

# %%
import Pkg
pkgs = [
    "BioSequences",
    "StatsPlots",
    "Random",
    "StatsBase",
    "PlotlyJS",
    "Primes",
    "BioSymbols",
    "DataFrames",
    "ProgressMeter",
    "Colors",
    "Measures"
]

Pkg.add(pkgs)
for pkg in pkgs
    eval(Meta.parse("import $pkg"))
end

StatsPlots.plotlyjs()
# Out:
#   Resolving package versions...
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [442fdcdd] + Measures v0.3.1
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
# Plots.PlotlyJSBackend()

# %%
function observe(sequence; error_rate = error_rate, alphabet = BioSymbols.ACGT)
    new_seq = Vector{eltype(sequence)}()
    for character in sequence
        if rand() > error_rate
            # match
            push!(new_seq, character)
        else
            error_type = rand(1:3)
            if error_type == 1
                # mismatch
                push!(new_seq, rand(setdiff(alphabet, character)))
            elseif error_type == 2
                # insertion
                push!(new_seq, rand(alphabet))
                push!(new_seq, character)
            else
                # deletion
                continue
            end
        end
    end
    return_seq = BioSequences.LongDNASeq(new_seq)
    if rand(Bool)
        return_seq = BioSequences.reverse_complement!(return_seq)
    end
    return return_seq
end
# Out:
# observe (generic function with 1 method)

# %%
results = 
DataFrames.DataFrame(
    k = [],
    error_rate = [],
    sequence_length = [],
    coverage = [],
    unique_kmers = [])

iteration = 1
ProgressMeter.@showprogress for k in Primes.primes(3, 31)
    KMER_TYPE = BioSequences.DNAMer{k}
    for sequence_length in [10^i for i in 2:4]
        for error_rate in [0.0, 0.001, 0.01, 0.1]
            for coverage in [10^i for i in 1:3]
                sequence = BioSequences.randdnaseq(Random.seed!(iteration), sequence_length)
                kmers = Set{KMER_TYPE}()
                for i in 1:coverage
                    observed_sequence = observe(sequence, error_rate = error_rate) 
                    for kmer_set in BioSequences.each(KMER_TYPE, observed_sequence)
                        push!(kmers, BioSequences.canonical(kmer_set.fw))
                    end
                end
                unique_kmers = length(kmers)
                result = (
                        k = k,
                        error_rate = error_rate,
                        sequence_length = sequence_length,
                        coverage = coverage,
                        unique_kmers = unique_kmers
                        )
                push!(results, result)
                iteration += 1
            end
        end
    end
end

# %%
error_to_linestyles = Dict(
    a => b for (a, b) in zip(sort(unique(results[!, "error_rate"])), [:solid, :dash, :dot, :dashdot])
)
# Out:
# Dict{Float64,Symbol} with 4 entries:
#   0.0   => :solid
#   0.01  => :dot
#   0.1   => :dashdot
#   0.001 => :dash

# %%
coverage_to_markershape = Dict(
    a => b for (a, b) in zip(sort(unique(results[!, "coverage"])), [:circle, :rect, :cross])
)
# Out:
# Dict{Int64,Symbol} with 3 entries:
#   100  => :rect
#   10   => :circle
#   1000 => :cross

# %%
for sequence_length in sort(unique(results[!, "sequence_length"]))
    p = StatsPlots.plot(
        title = "Sequence Length : $(sequence_length)",
        xlabel = "k",
        ylabel = "# unique observed kmers",
        legend = :outertopright,
        size = (700, 500),
        leftmargin = 5(Measures.mm)
    )

    for error_rate in sort(unique(results[!, "error_rate"]))
        for coverage in sort(unique(results[!, "coverage"]))
            indices = (
                (results[!, "sequence_length"] .== sequence_length) .&
                (results[!, "error_rate"] .== error_rate) .&
                (results[!, "coverage"] .== coverage))
            xs = results[indices, "k"]
            ys = results[indices, "unique_kmers"]

            p = StatsPlots.plot!(p,
                xs,
                ys,
                xticks = (xs, string.(xs)),
                linestyle = error_to_linestyles[error_rate],
                markershape = coverage_to_markershape[coverage],
                label = "error_rate: $(rpad(error_rate, 5, '0')) | coverage:$(coverage)"
            )
        end
    end
    # displays in notebook
    display(p)
    
    # displays on website
    filename = "/assets/images/2020-12-19-observed-kmers-vs-error-rate-$(sequence_length).html"
    StatsPlots.savefig(p, dirname(pwd()) * filename)
    display("text/html", "![]($filename)")
end
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.57.1.min.js"></script>
#     </head>
#     <body>
#             <div id="cb9c1c28-3be8-40dc-aa37-9c32eee8e32f" style="width:700px;height:500px;"></div>
#     <script>
#     PLOT = document.getElementById('cb9c1c28-3be8-40dc-aa37-9c32eee8e32f');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             92.0,
#             94.0,
#             90.0,
#             88.0,
#             84.0,
#             82.0,
#             78.0,
#             72.0,
#             70.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(227, 111, 71, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(227, 111, 71, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             31.0,
#             94.0,
#             92.0,
#             90.0,
#             88.0,
#             84.0,
#             82.0,
#             78.0,
#             72.0,
#             70.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(62, 164, 78, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(62, 164, 78, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             29.0,
#             84.0,
#             94.0,
#             90.0,
#             88.0,
#             84.0,
#             82.0,
#             78.0,
#             72.0,
#             70.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(195, 113, 210, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(195, 113, 210, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             30.0,
#             83.0,
#             94.0,
#             103.0,
#             88.0,
#             109.0,
#             101.0,
#             78.0,
#             86.0,
#             100.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(172, 142, 24, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(172, 142, 24, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             31.0,
#             121.0,
#             169.0,
#             155.0,
#             216.0,
#             157.0,
#             143.0,
#             237.0,
#             251.0,
#             324.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(0, 170, 174, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 170, 174, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             331.0,
#             506.0,
#             889.0,
#             1169.0,
#             1239.0,
#             1452.0,
#             1507.0,
#             2105.0,
#             1999.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.010 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.010 | cover
# ![](/assets/images/2020-12-19-observed-kmers-vs-error-rate-100.html)
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.57.1.min.js"></script>
#     </head>
#     <body>
#             <div id="d2f22948-fa26-4b7a-b923-9f39ba903139" style="width:700px;height:500px;"></div>
#     <script>
#     PLOT = document.getElementById('d2f22948-fa26-4b7a-b923-9f39ba903139');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             437.0,
#             930.0,
#             990.0,
#             987.0,
#             984.0,
#             982.0,
#             978.0,
#             972.0,
#             970.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(227, 111, 71, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(227, 111, 71, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             440.0,
#             936.0,
#             989.0,
#             988.0,
#             984.0,
#             982.0,
#             978.0,
#             972.0,
#             970.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(62, 164, 78, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(62, 164, 78, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             442.0,
#             936.0,
#             989.0,
#             988.0,
#             984.0,
#             982.0,
#             978.0,
#             972.0,
#             970.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(195, 113, 210, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(195, 113, 210, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             458.0,
#             1007.0,
#             1073.0,
#             1084.0,
#             1134.0,
#             1244.0,
#             1145.0,
#             1242.0,
#             1120.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(172, 142, 24, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(172, 142, 24, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             481.0,
#             1371.0,
#             2025.0,
#             2171.0,
#             2441.0,
#             2597.0,
#             2839.0,
#             3801.0,
#             4009.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(0, 170, 174, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 170, 174, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             512.0,
#             4438.0,
#             10292.0,
#             11906.0,
#             14584.0,
#             16477.0,
#             20330.0,
#             25808.0,
#             27194.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.010 | coverage:10",
#         "zmin"
# ![](/assets/images/2020-12-19-observed-kmers-vs-error-rate-1000.html)
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.57.1.min.js"></script>
#     </head>
#     <body>
#             <div id="70a4dd33-5f73-4913-ac69-b905b1752cfe" style="width:700px;height:500px;"></div>
#     <script>
#     PLOT = document.getElementById('70a4dd33-5f73-4913-ac69-b905b1752cfe');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             512.0,
#             5723.0,
#             9973.0,
#             9986.0,
#             9984.0,
#             9982.0,
#             9978.0,
#             9972.0,
#             9970.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(227, 111, 71, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(227, 111, 71, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             512.0,
#             5756.0,
#             9963.0,
#             9981.0,
#             9984.0,
#             9982.0,
#             9978.0,
#             9972.0,
#             9970.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(62, 164, 78, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(62, 164, 78, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             512.0,
#             5690.0,
#             9962.0,
#             9988.0,
#             9984.0,
#             9982.0,
#             9978.0,
#             9972.0,
#             9970.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(195, 113, 210, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(195, 113, 210, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             512.0,
#             5933.0,
#             11020.0,
#             11298.0,
#             11715.0,
#             11759.0,
#             12295.0,
#             12718.0,
#             12923.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(172, 142, 24, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(172, 142, 24, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             512.0,
#             7044.0,
#             19729.0,
#             22043.0,
#             25868.0,
#             27432.0,
#             31520.0,
#             37183.0,
#             38432.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(0, 170, 174, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 170, 174, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             32.0,
#             512.0,
#             8187.0,
#             97685.0,
#             117265.0,
#             151062.0,
#             167307.0,
#             204825.0,
#             259283.0,
#             273591.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "erro
# ![](/assets/images/2020-12-19-observed-kmers-vs-error-rate-10000.html)

# %% [markdown]
# This is very interesting to me!
# The top two lines in each of these plots have "cross" marker shapes, indicating 1000x coverage.
# This means that for these results, a 10x increase in coverage contributes more to overall noise than a 10x increase in error rate.
# These results also point to the divergence zone for erroneous noise out-pacing signal occurs at the k=7-11 mark.
#
#
# Because we can't see much beyond detail in the lower plots because of how much the `error_rate: 0.100 | coverage: 1000` results dominate the rest, we'll re-plot these with a log2(y) axis

# %%
for sequence_length in sort(unique(results[!, "sequence_length"]))
    p = StatsPlots.plot(
        title = "Sequence Length : $(sequence_length)",
        xlabel = "k",
        ylabel = "log2(# unique observed kmers)",
        legend = :outertopright,
        size = (700, 500),
        leftmargin = 5(Measures.mm)
    )

    for error_rate in sort(unique(results[!, "error_rate"]))
        for coverage in sort(unique(results[!, "coverage"]))
            indices = (
                (results[!, "sequence_length"] .== sequence_length) .&
                (results[!, "error_rate"] .== error_rate) .&
                (results[!, "coverage"] .== coverage))
            xs = results[indices, "k"]
            ys = results[indices, "unique_kmers"]

            p = StatsPlots.plot!(p,
                xs,
                log2.(ys),
                xticks = (xs, string.(xs)),
                linestyle = error_to_linestyles[error_rate],
                markershape = coverage_to_markershape[coverage],
                label = "error_rate: $(rpad(error_rate, 5, '0')) | coverage:$(coverage)"
            )
        end
    end
    # displays in notebook
    display(p)
    
    # displays on website
    filename = "/assets/images/2020-12-19-observed-kmers-vs-error-rate-$(sequence_length).log-transform.html"
    StatsPlots.savefig(p, dirname(pwd()) * filename)
    display("text/html", "![]($filename)")
end
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.57.1.min.js"></script>
#     </head>
#     <body>
#             <div id="15785024-7808-4de5-af2f-8ddddcc1f01f" style="width:700px;height:500px;"></div>
#     <script>
#     PLOT = document.getElementById('15785024-7808-4de5-af2f-8ddddcc1f01f');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             6.523561956057013,
#             6.554588851677638,
#             6.491853096329675,
#             6.459431618637297,
#             6.392317422778761,
#             6.357552004618084,
#             6.285402218862249,
#             6.169925001442312,
#             6.129283016944966
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(227, 111, 71, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(227, 111, 71, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             4.954196310386875,
#             6.554588851677638,
#             6.523561956057013,
#             6.491853096329675,
#             6.459431618637297,
#             6.392317422778761,
#             6.357552004618084,
#             6.285402218862249,
#             6.169925001442312,
#             6.129283016944966
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(62, 164, 78, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(62, 164, 78, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             4.857980995127572,
#             6.392317422778761,
#             6.554588851677638,
#             6.491853096329675,
#             6.459431618637297,
#             6.392317422778761,
#             6.357552004618084,
#             6.285402218862249,
#             6.169925001442312,
#             6.129283016944966
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(195, 113, 210, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(195, 113, 210, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             4.906890595608519,
#             6.3750394313469245,
#             6.554588851677638,
#             6.6865005271832185,
#             6.459431618637297,
#             6.768184324776926,
#             6.658211482751795,
#             6.285402218862249,
#             6.426264754702098,
#             6.643856189774724
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(172, 142, 24, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(172, 142, 24, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             4.954196310386875,
#             6.918863237274595,
#             7.400879436282184,
#             7.2761244052742375,
#             7.754887502163468,
#             7.294620748891627,
#             7.159871336778389,
#             7.888743248898259,
#             7.971543553950772,
#             8.339850002884624
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(0, 170, 174, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 170, 174, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             8.370687406807217,
#             8.98299357469431,
#             9.796039608829
# ![](/assets/images/2020-12-19-observed-kmers-vs-error-rate-100.log-transform.html)
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.57.1.min.js"></script>
#     </head>
#     <body>
#             <div id="25c204cc-b63e-4858-bc8d-d6cc620f80d1" style="width:700px;height:500px;"></div>
#     <script>
#     PLOT = document.getElementById('25c204cc-b63e-4858-bc8d-d6cc620f80d1');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             8.7714894695006,
#             9.861086905995395,
#             9.951284714966972,
#             9.946906274456397,
#             9.94251450533924,
#             9.939579214314692,
#             9.933690654952233,
#             9.92481250360578,
#             9.92184093707449
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(227, 111, 71, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(227, 111, 71, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             8.78135971352466,
#             9.870364719583405,
#             9.94982671075911,
#             9.948367231584678,
#             9.94251450533924,
#             9.939579214314692,
#             9.933690654952233,
#             9.92481250360578,
#             9.92184093707449
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(62, 164, 78, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(62, 164, 78, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             8.787902559391432,
#             9.870364719583405,
#             9.94982671075911,
#             9.948367231584678,
#             9.94251450533924,
#             9.939579214314692,
#             9.933690654952233,
#             9.92481250360578,
#             9.92184093707449
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(195, 113, 210, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(195, 113, 210, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             8.839203788096944,
#             9.975847968006784,
#             10.067434360756522,
#             10.08214904135387,
#             10.147204924942228,
#             10.280770770130603,
#             10.161131882984307,
#             10.278449458220482,
#             10.129283016944967
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(172, 142, 24, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(172, 142, 24, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             8.909893083770042,
#             10.421012855779226,
#             10.98370619265935,
#             11.084144010615145,
#             11.253256579781153,
#             11.342630298678408,
#             11.471167133724391,
#             11.892163309861965,
#             11.96902670215077
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(0, 170, 174, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 170, 174, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             9.0,
#             12.115693952197011,
#             13.3292357417338,
#             13.539401179028113,
#             13.832098846039134,
# ![](/assets/images/2020-12-19-observed-kmers-vs-error-rate-1000.log-transform.html)
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.57.1.min.js"></script>
#     </head>
#     <body>
#             <div id="758fe541-4708-4292-b4ec-5571d659e7b1" style="width:700px;height:500px;"></div>
#     <script>
#     PLOT = document.getElementById('758fe541-4708-4292-b4ec-5571d659e7b1');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             9.0,
#             12.48255589154897,
#             13.283811834830894,
#             13.285691191330093,
#             13.285402218862249,
#             13.285113188501493,
#             13.284534954008425,
#             13.283667167491501,
#             13.283377789285558
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(227, 111, 71, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(227, 111, 71, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             9.0,
#             12.490850876740298,
#             13.282364508223864,
#             13.284968651604022,
#             13.285402218862249,
#             13.285113188501493,
#             13.284534954008425,
#             13.283667167491501,
#             13.283377789285558
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.000 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.000 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(62, 164, 78, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(62, 164, 78, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             9.0,
#             12.474212937193943,
#             13.282219695672588,
#             13.285980105928212,
#             13.285402218862249,
#             13.285113188501493,
#             13.284534954008425,
#             13.283667167491501,
#             13.283377789285558
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:10",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:10",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(195, 113, 210, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(195, 113, 210, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             9.0,
#             12.534546067459992,
#             13.42783660345852,
#             13.463779785335385,
#             13.516069333750497,
#             13.521477756357788,
#             13.585784114483445,
#             13.6345841934937,
#             13.657653401803715
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:100",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:100",
#         "marker": {
#             "symbol": "square",
#             "color": "rgba(172, 142, 24, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(172, 142, 24, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             9.0,
#             12.782179193831208,
#             14.268030211860133,
#             14.428032964193013,
#             14.658880895047878,
#             14.743572188935634,
#             14.943979914343739,
#             15.182355554070389,
#             15.230020435705635
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             3.0,
#             5.0,
#             7.0,
#             11.0,
#             13.0,
#             17.0,
#             19.0,
#             23.0,
#             29.0,
#             31.0
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "error_rate: 0.001 | coverage:1000",
#         "zmin": null,
#         "legendgroup": "error_rate: 0.001 | coverage:1000",
#         "marker": {
#             "symbol": "cross",
#             "color": "rgba(0, 170, 174, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 170, 174, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             9.0,
#             12.999119179995297,
#             16.575849426011033,
#             16.83941295190226,
#             17.204781267260344,
#             17.352138282359512,
# ![](/assets/images/2020-12-19-observed-kmers-vs-error-rate-10000.log-transform.html)

# %% [markdown]
# In the above plots, we can divergence points for each of the sequence lengths:
# - 100bp sequence
#     - 3
# - 1,000bp
#     - 5
# - 10,000bp
#     - 7
#
# I don't know if this pattern will hold in in practice on real data (these sequencs are simulated without any attention paid to real genetic grammar), but these breakpoints appear to follow a log4(sequence_length) pattern:

# %%
Int(round(log(4, 100)))
# Out:
# 3

# %%
Int(round(log(4, 1000)))
# Out:
# 5

# %%
Int(round(log(4, 10000)))
# Out:
# 7
